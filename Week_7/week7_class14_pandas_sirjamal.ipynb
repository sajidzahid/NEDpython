# %%
import pandas as pd

# %%
# Series single column of data.
# Dataframe

import pandas as pd
array1 = [1,9,10,11]
series1 = pd.Series(array1)
display(series1)
print(type(series1))
# Out:
# 0     1
# 1     9
# 2    10
# 3    11
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
series1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
calories = {"Day1":320, "Day2":500, "Day3":700, "Day4":900}
series2 = pd.Series(calories)
display(series2)
# Out:
# Day1    320
# Day2    500
# Day3    700
# Day4    900
# dtype: int64

# %% [markdown]
# # Data Frames

# %%
data ={
    "days": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"],
    "Calories": [100,200,300,400,500,600,700],
    "Gym": [True, False, False, False, True, True, True]
}
df = pd.DataFrame(data)
display(df)
# Out:
#         days  Calories    Gym
# 0     Monday       100   True
# 1    Tuesday       200  False
# 2  Wednesday       300  False
# 3   Thursday       400  False
# 4     Friday       500   True
# 5   Saturday       600   True
# 6     Sunday       700   True

# %%
df.loc[3:6]
# Out:
#        days  Calories    Gym
# 3  Thursday       400  False
# 4    Friday       500   True
# 5  Saturday       600   True
# 6    Sunday       700   True

# %%
df.loc[4]
# Out:
# days        Friday
# Calories       500
# Gym           True
# Name: 4, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (7, 3)

# %%
list(df.columns)
# Out:
# ['days', 'Calories', 'Gym']

# %%
list(df.index )
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
list(df.values)
# Out:
# [array(['Monday', 100, True], dtype=object),
#  array(['Tuesday', 200, False], dtype=object),
#  array(['Wednesday', 300, False], dtype=object),
#  array(['Thursday', 400, False], dtype=object),
#  array(['Friday', 500, True], dtype=object),
#  array(['Saturday', 600, True], dtype=object),
#  array(['Sunday', 700, True], dtype=object)]

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
df.loc # to Locate

# %%
df.iloc[3:6,0:2] #
# Out:
#        days  Calories
# 3  Thursday       400
# 4    Friday       500
# 5  Saturday       600

# %%
pandas1 = [method for method in dir(pd) if not method.startswith('__')] # Pandas Method
for function, method in enumerate(pandas1):
    print(f'{function+1}. {method}')
# Out:
# 1. ArrowDtype
# 2. BooleanDtype
# 3. Categorical
# 4. CategoricalDtype
# 5. CategoricalIndex
# 6. DataFrame
# 7. DateOffset
# 8. DatetimeIndex
# 9. DatetimeTZDtype
# 10. ExcelFile
# 11. ExcelWriter
# 12. Flags
# 13. Float32Dtype
# 14. Float64Dtype
# 15. Grouper
# 16. HDFStore
# 17. Index
# 18. IndexSlice
# 19. Int16Dtype
# 20. Int32Dtype
# 21. Int64Dtype
# 22. Int8Dtype
# 23. Interval
# 24. IntervalDtype
# 25. IntervalIndex
# 26. MultiIndex
# 27. NA
# 28. NaT
# 29. NamedAgg
# 30. Period
# 31. PeriodDtype
# 32. PeriodIndex
# 33. RangeIndex
# 34. Series
# 35. SparseDtype
# 36. StringDtype
# 37. Timedelta
# 38. TimedeltaIndex
# 39. Timestamp
# 40. UInt16Dtype
# 41. UInt32Dtype
# 42. UInt64Dtype
# 43. UInt8Dtype
# 44. _built_with_meson
# 45. _config
# 46. _is_numpy_dev
# 47. _libs
# 48. _pandas_datetime_CAPI
# 49. _pandas_parser_CAPI
# 50. _testing
# 51. _typing
# 52. _version_meson
# 53. annotations
# 54. api
# 55. array
# 56. arrays
# 57. bdate_range
# 58. compat
# 59. concat
# ...

# %%
dataframes = [method for method in dir(df) if not method.startswith('__')]  # Data Frames Mehtods
for function, method in enumerate(dataframes):
    print(f'{function+1}. {method}')
# Out:
# 1. Calories
# 2. Gym
# 3. T
# 4. _AXIS_LEN
# 5. _AXIS_ORDERS
# 6. _AXIS_TO_AXIS_NUMBER
# 7. _HANDLED_TYPES
# 8. _accessors
# 9. _accum_func
# 10. _agg_examples_doc
# 11. _agg_see_also_doc
# 12. _align_for_op
# 13. _align_frame
# 14. _align_series
# 15. _append
# 16. _arith_method
# 17. _arith_method_with_reindex
# 18. _as_manager
# 19. _attrs
# 20. _box_col_values
# 21. _can_fast_transpose
# 22. _check_inplace_and_allows_duplicate_labels
# 23. _check_is_chained_assignment_possible
# 24. _check_label_or_level_ambiguity
# 25. _check_setitem_copy
# 26. _clear_item_cache
# 27. _clip_with_one_bound
# 28. _clip_with_scalar
# 29. _cmp_method
# 30. _combine_frame
# 31. _consolidate
# 32. _consolidate_inplace
# 33. _construct_axes_dict
# 34. _construct_result
# 35. _constructor
# 36. _constructor_from_mgr
# 37. _constructor_sliced
# 38. _constructor_sliced_from_mgr
# 39. _create_data_for_split_and_tight_to_dict
# 40. _data
# 41. _deprecate_downcast
# 42. _dir_additions
# 43. _dir_deletions
# ...

# %%
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols: 'UsecolsArgType' = None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters: 'Mapping[Hashable, Callable] | None' = None, true_values: 'list | None' = None, false_values: 'list | None' = None, skipinitialspace: 'bool' = False, skiprows: 'list[int] | int | Callable[[Hashable], bool] | None' = None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values: 'Hashable | Iterable[Hashable] | Mapping[Hashable, Iterable[Hashable]] | None' = None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool | lib.NoDefault' = <no_defau
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/Titanic-Dataset.csv")
df.shape
# Out:
# (891, 12)

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df["Fare_class"]  = df.Fare/df.Pclass

# %%
df ["Fare_class"] = ""
for i in df.index:
  if df.loc[i, "Fare"] > 70:
    df.loc[i,"Fare_class"]= "elite"
  elif df.loc[i, "Fare"] > 30 and df.loc[i,"Fare"] < 69:
    df.loc[i,"Fare_class"]= "Avergae"
  else:
    df.loc[i,"Fare_class"]= "Basic"

# %%
for col in df.columns:
    print(f"\nColumn: {col}")
df[col]
# Out:
# Column: PassengerId
#
# Column: Survived
#
# Column: Pclass
#
# Column: Name
#
# Column: Sex
#
# Column: Age
#
# Column: SibSp
#
# Column: Parch
#
# Column: Ticket
#
# Column: Fare
#
# Column: Cabin
#
# Column: Embarked
#
# Column: Fare_class
# 0       2.416667
# 1      71.283300
# 2       2.641667
# 3      53.100000
# 4       2.683333
#          ...
# 886     6.500000
# 887    30.000000
# 888     7.816667
# 889    30.000000
# 890     2.583333
# Name: Fare_class, Length: 891, dtype: float64

# %%
df.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# prompt: draw a file column wise

import pandas as pd

# Assuming your data is in a CSV file named 'your_file.csv'
# Replace 'your_file.csv' with the actual filename if different
try:
    df = pd.read_csv('your_file.csv')
except FileNotFoundError:
    print("Error: 'your_file.csv' not found. Please ensure the file exists in the current directory or provide the correct path.")
    exit()


# Display each column individually
for col in df.columns:
    print(f"\nColumn: {col}")
df[col]

# %%
# Data Aggregation
# Group By , reduces the Data/sums it up

# %%
survival_rate = df.groupby("Survived")

# %%
survival_rate = df.groupby(["Survived"])["Fare"].sum().reset_index()
survival_rate
# Out:
#    Survived        Fare
# 0         0  12142.7199
# 1         1  16551.2294

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Fare_class   891 non-null    float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 90.6+ KB

# %%
# prompt: use data filter in df

# Assuming 'df' is your DataFrame (loaded from 'your_file.csv' or otherwise defined)

# Example 1: Filter rows where 'Age' is greater than 30
filtered_df = df[df['Age'] > 30]
print(filtered_df.head())  # Print the first few rows of the filtered DataFrame


# Example 2: Filter rows where 'Pclass' is 1 and 'Survived' is 1
filtered_df = df[(df['Pclass'] == 1) & (df['Survived'] == 1)]
print(filtered_df.head())

# Example 3: Filter rows where 'Embarked' is either 'C' or 'Q'
filtered_df = df[df['Embarked'].isin(['C', 'Q'])]
print(filtered_df.head())


# Example 4: Filter rows where 'Name' contains 'Mr.'
filtered_df = df[df['Name'].str.contains('Mr.')]
print(filtered_df.head())

# Example 5: Filter out rows with missing values in 'Age' column
filtered_df = df.dropna(subset=['Age'])
print(filtered_df.head())

# %%
filtered_df = df[df['Age'] > 30]
print(filtered_df.head())  # Print the first few rows of the filtered DataFrame
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Fare_class
# 1       0  PC 17599  71.2833   C85        C   71.283300
# 3       0    113803  53.1000  C123        S   53.100000
# 4       0    373450   8.0500   NaN        S    2.683333
# 6       0     17463  51.8625   E46        S   51.862500
# ...

# %%
df["Fare_class"].value_counts()
# Out:
# Fare_class
# 2.683333     43
# 6.500000     42
# 2.631933     38
# 2.583333     34
# 13.000000    29
#              ..
# 2.286100      1
# 6.325000      1
# 2.884733      1
# 2.576400      1
# 3.505567      1
# Name: count, Length: 250, dtype: int64

# %%
counts.plot(kind="bar")
# Out:
# <Axes: xlabel='Fare_class'>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(counts.index, counts.values)
# Out:
# <BarContainer object of 250 artists>

# %%
import pandas as pd

# %%
pd.concat([counts,survival_rate], axis = 1)
# Out:
#            count  Survived        Fare
# 2.683333    43.0       NaN         NaN
# 6.500000    42.0       NaN         NaN
# 2.631933    38.0       NaN         NaN
# 2.583333    34.0       NaN         NaN
# 13.000000   29.0       NaN         NaN
# ...          ...       ...         ...
# 6.325000     1.0       NaN         NaN
# 2.884733     1.0       NaN         NaN
# 2.576400     1.0       NaN         NaN
# 3.505567     1.0       NaN         NaN
# 1.000000     NaN       1.0  16551.2294
#
# [251 rows x 3 columns]

# %%
pd.concat([counts,survival_rate], axis = 1).to_csv("concat.csv") # To Generate the file.

# %%
import numpy as np
