# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'], 30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}

# %%
# Create a DataFrame
df = pd.DataFrame(data)

# Group by category and calculate the mean rating
category_ratings = df.groupby('Category')['Rating'].mean()

# Plotting
plt.figure(figsize=(10, 6))
category_ratings.plot(kind='line', color='skyblue')
plt.title('Average Rating by Category')
plt.xlabel('Category')
plt.ylabel('Average Rating')
plt.ylim(0, 5)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
plt.plot(ages_x, dev_y, label='All Devs')
plt.plot(ages_x, py_dev_y, label='Python')
plt.plot(ages_x, js_dev_y, label='JS')
plt.title("Median Salary (USD) by Age")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")


# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot

plt.legend()
plt.show()

# %%
plt.plot(ages_x,dev_y,lable='All Devs')
plt.plot(ages_x,dev_y,lable='python')
plt.plot(ages_x,dev_y,lable='JS')

plt.title('Median Salary (USD) by Age')
plt.xlable("Ages")
plt.ylable('Median Salary (USD)' )

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plt.plot(ages_x,dev_y,lable='All Devs')
#       2 plt.plot(ages_x,dev_y,lable='python')
#       3 plt.plot(ages_x,dev_y,lable='JS')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3578, in plot(scalex, scaley, data, *args, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.plot)
#    3571 def plot(
#    3572     *args: float | ArrayLike | str,
#    (...)
#    3576     **kwargs,
#    3577 ) -> list[Line2D]:
# -> 3578     return gca().plot(
#    3579         *args,
#    3580         scalex=scalex,
#    3581         scaley=scaley,
#    3582         **({"data": data} if data is not None else {}),
#    3583         **kwargs,
#    3584     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
# ...

# %%
plt.plot(ages_x, dev_y, label='All Devs')
plt.plot(ages_x, py_dev_y, label='Python')
# plt.plot(ages_x, js_dev_y, label='JS')
# plt.title("Median Salary (USD) by Age")
# plt.xlabel("Ages")
# plt.ylabel("Median Salary (USD)")


# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot

plt.legend()
plt.show()

# %%
plt.plot(ages_x, dev_y,'^k--', label='All Devs')
plt.plot(ages_x, py_dev_y,'red', label='Python')
plt.plot(ages_x, js_dev_y, label='JS')
plt.title("Median Salary (USD) by Age")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")


# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot

plt.legend()
plt.show()

# %%
plt.plot(ages_x, dev_y,'^k--', label='All Devs')
plt.plot(ages_x, py_dev_y,'red', label='Python')
plt.plot(ages_x, js_dev_y, label='JS')
plt.title("Median Salary (USD) by Age")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.grid()

# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot

plt.legend()
plt.show()

# %%
plt.plot(ages_x, dev_y,'^k--', label='All Devs')
plt.plot(ages_x, py_dev_y,'red', label='Python')
plt.plot(ages_x, js_dev_y, label='JS')
plt.title("Median Salary (USD) by Age")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.grid(True)

# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot
plt.tight_layout()
plt.legend()
plt.show()

# %%
plt.xkcd()
plt.plot(ages_x, dev_y,'^k--', label='All Devs')
plt.plot(ages_x, py_dev_y,'red', label='Python')
plt.plot(ages_x, js_dev_y, label='JS')
plt.title("Median Salary (USD) by Age")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.grid(True)

# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot
plt.tight_layout()
plt.legend()
plt.savefig('plot1-1.png')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %%
plt.bar(ages_x, dev_y,'^k--', label='All Devs')
plt.bar(ages_x, py_dev_y,'red', label='Python')
plt.bar(ages_x, js_dev_y, label='JS')
plt.title("Median Salary (USD) by Age")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.grid(True)

# adding legend
# method 1
# plt.legend(['All Devs', 'Python'])
# method 2 - pass a label argument to plot
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2254, in Axes._convert_dx(dx, x0, xconv, convert)
#    2253     delist = True
# -> 2254 dx = [convert(x0 + ddx) - x for ddx in dx]
#    2255 if delist:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2254, in <listcomp>(.0)
#    2253     delist = True
# -> 2254 dx = [convert(x0 + ddx) - x for ddx in dx]
#    2255 if delist:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# ...
